# %%
import pandas as pd
realtrump = pd.read_csv('realdonaldtrump.csv')
realtrump
# Out:
#                         id                                               link  \
# 0               1698308935  https://twitter.com/realDonaldTrump/status/169...
# 1               1701461182  https://twitter.com/realDonaldTrump/status/170...
# 2               1737479987  https://twitter.com/realDonaldTrump/status/173...
# 3               1741160716  https://twitter.com/realDonaldTrump/status/174...
# 4               1773561338  https://twitter.com/realDonaldTrump/status/177...
# ...                    ...                                                ...
# 43347  1273405198698975232  https://twitter.com/realDonaldTrump/status/127...
# 43348  1273408026968457216  https://twitter.com/realDonaldTrump/status/127...
# 43349  1273442195161387008  https://twitter.com/realDonaldTrump/status/127...
# 43350  1273442469066276864  https://twitter.com/realDonaldTrump/status/127...
# 43351  1273442528411385858  https://twitter.com/realDonaldTrump/status/127...
#
# ...

# %% [markdown]
# # trump가 가장 많이 사용한 단어, 해시태그, 멘션을 단어 구름으로
# => 트럼프가 트위터를 통해 전하고 싶은 내용

# %%
#결측치 조회
print(realtrump.info(), realtrump.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43352 entries, 0 to 43351
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         43352 non-null  int64
#  1   link       43352 non-null  object
#  2   content    43352 non-null  object
#  3   date       43352 non-null  object
#  4   retweets   43352 non-null  int64
#  5   favorites  43352 non-null  int64
#  6   mentions   20386 non-null  object
#  7   hashtags   5583 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 2.6+ MB
# None id               0
# link             0
# content          0
# date             0
# retweets         0
# favorites        0
# mentions     22966
# hashtags     37769
# dtype: int64

# %% [markdown]
# mentions와 hashtags는 결측치가 많으므로 월별은 안쓰는 게 좋을 듯

# %%
#content에서 picture 제거
content_tweet = realtrump[~realtrump['content'].str.contains('pic.twitter.com/')]
content_tweet.reset_index(drop = True, inplace = True)
content_tweet
# Out:
#                         id                                               link  \
# 0               1698308935  https://twitter.com/realDonaldTrump/status/169...
# 1               1701461182  https://twitter.com/realDonaldTrump/status/170...
# 2               1737479987  https://twitter.com/realDonaldTrump/status/173...
# 3               1741160716  https://twitter.com/realDonaldTrump/status/174...
# 4               1773561338  https://twitter.com/realDonaldTrump/status/177...
# ...                    ...                                                ...
# 39662  1273061883399098368  https://twitter.com/realDonaldTrump/status/127...
# 39663  1273080720794279937  https://twitter.com/realDonaldTrump/status/127...
# 39664  1273095002563006472  https://twitter.com/realDonaldTrump/status/127...
# 39665  1273405198698975232  https://twitter.com/realDonaldTrump/status/127...
# 39666  1273408026968457216  https://twitter.com/realDonaldTrump/status/127...
#
# ...

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\yttn0\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from collections import Counter
from nltk.corpus import stopwords
import re
# 단어만
word = []
stop_words = set(stopwords.words('english')) #불용어(영어)
stop_words.update(('and'))
for i in content_tweet['content']:
    i = re.sub(r'[^ A-Za-z]','', i)
    i.replace('@', '').replace('#', '') # mention이랑 hashtag문자 삭제
    for w in i.lower().split():
        if w not in stop_words :#불용어 제거
           word.append(w)
print(Counter(word).most_common(n = 10))# 제일 많은 단어 10개 출력
# Out:
# [('realdonaldtrump', 8246), ('great', 5919), ('trump', 5508), ('president', 2770), ('people', 2525), ('thank', 2231), ('thanks', 2096), ('us', 2081), ('would', 1962), ('get', 1845)]

# %% [markdown]
# # 월별로 가장 많이 사용한 단어 막대 그래프 (위의 단어 구름에 있는 것들을)
# => 월별로 이슈

# %% [markdown]
# # 월별 리트윗 막대 그래프
# => 어떤 단어가 가장 이슈였나
